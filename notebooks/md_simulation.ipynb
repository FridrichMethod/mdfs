# %% [markdown]
# # Molecular dynamics from scratch: poly-alanine
#
# An end-to-end demo of the `mdfs` library on the bundled 10-residue polyalanine
# (`assets/poly_A.pdb`):
#
# 1. add hydrogens and assign Amber **ff19SB** parameters (via OpenMM)
# 2. build a differentiable energy function (forces come from `jax.grad`)
# 3. energy-minimize the structure
# 4. run **NVT** (Langevin/BAOAB) dynamics at 300 K
# 5. write a trajectory + energy log and plot temperature and C-alpha RMSD
#
# Units are the OpenMM convention throughout: nm, ps, amu, kJ/mol, e.
#
# > **Note:** mdfs omits the ff19SB backbone CMAP correction (documented limitation);
# > all other bonded (incl. impropers) and nonbonded terms match OpenMM exactly.

# %%
import logging

import jax

jax.config.update("jax_enable_x64", True)  # tiny system; favor accuracy

import jax.numpy as jnp
import matplotlib.pyplot as plt
import mdtraj as md
import numpy as np

import mdfs
from mdfs.utils import configure_logging

configure_logging(logging.WARNING)
print("JAX devices:", jax.devices())

# %% [markdown]
# ## 1. Parameterize the system
#
# `system_params_from_pdb` loads the PDB, adds hydrogens at pH 7, builds an OpenMM
# `System` with ff19SB, and reads fully-resolved per-instance parameters.

# %%
sp, openmm_top = mdfs.system_params_from_pdb("../assets/poly_A.pdb")
print(
    f"atoms={sp.n_atoms}  bonds={len(sp.bonds)}  angles={len(sp.angles)}  "
    f"torsions={len(sp.torsions)}  exceptions={len(sp.exclude_pairs)}"
)

bonded = mdfs.to_bonded_set(sp)
nonbonded = mdfs.to_nonbonded_set(sp)  # dense (N, N) path: fast autodiff forces
energy_fn, _shift, _box = mdfs.make_energy_fn(None, bonded, nonbonded)
R_init = jnp.asarray(sp.positions)
print(f"initial potential energy = {float(energy_fn(R_init)):.2f} kJ/mol")

# %% [markdown]
# ## 2. Energy minimization
#
# Relax the freshly-protonated structure before dynamics (BFGS over the energy).

# %%
result = mdfs.minimize_energy(energy_fn, R_init, max_iter=500)
print(f"minimized: {result.initial_energy:.1f} -> {result.energy:.1f} kJ/mol")
R0 = result.positions

# %% [markdown]
# ## 3. NVT dynamics (Langevin / BAOAB) at 300 K
#
# Hydrogens are integrated explicitly (no constraints), so we use a small timestep
# (`dt = 0.5 fs`). Reporters collect the trajectory and an energy/temperature log.

# %%
temperature_K = 300.0
key = jax.random.PRNGKey(0)
V0 = mdfs.maxwell_boltzmann_velocities(key, sp.masses, temperature_K, sp.n_atoms)

state, step_fn = mdfs.simulate_langevin(
    R0, V0, box=None, bonded=bonded, nonbonded=nonbonded,
    dt=0.0005, mass=sp.masses, gamma=10.0, temperature=temperature_K,
)

traj_recorder = mdfs.TrajectoryRecorder(mdfs.mdtraj_topology_from_openmm(openmm_top))
energy_logger = mdfs.EnergyLogger(energy_fn, sp.masses, log_to_logger=False)
reporter = mdfs.combine_callbacks(traj_recorder, energy_logger)

state = mdfs.run(
    step_fn, state, n_steps=6000, key=jax.random.PRNGKey(1),
    report_interval=50, callback=reporter,
)
print("done:", len(energy_logger.records), "frames recorded")

# %% [markdown]
# ## 4. Energy and temperature

# %%
rec = energy_logger.records
t = np.array([r["time_ps"] for r in rec])
temp = np.array([r["temperature_K"] for r in rec])
pe = np.array([r["potential_kj_mol"] for r in rec])
tot = np.array([r["total_kj_mol"] for r in rec])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4))
ax1.plot(t, temp, lw=0.8)
ax1.axhline(temperature_K, color="r", ls="--", label=f"target {temperature_K:.0f} K")
ax1.axhline(temp[len(temp) // 2:].mean(), color="k", ls=":",
            label=f"mean {temp[len(temp) // 2:].mean():.0f} K")
ax1.set(xlabel="time (ps)", ylabel="temperature (K)", title="Thermostat")
ax1.legend()
ax2.plot(t, pe, lw=0.8, label="potential")
ax2.plot(t, tot, lw=0.8, label="total")
ax2.set(xlabel="time (ps)", ylabel="energy (kJ/mol)", title="Energy")
ax2.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. C-alpha RMSD

# %%
traj = traj_recorder.to_trajectory()
traj.superpose(traj, 0)
ca = traj.topology.select("name CA")
rmsd_nm = md.rmsd(traj, traj, 0, atom_indices=ca)

plt.figure(figsize=(7, 4))
plt.plot(traj.time, rmsd_nm * 10.0, lw=0.8)  # nm -> angstrom
plt.xlabel("time (ps)")
plt.ylabel(r"C$\alpha$ RMSD ($\AA$)")
plt.title("Backbone RMSD vs. initial frame")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Save outputs
#
# (Gitignored: trajectory and energy log.)

# %%
traj_recorder.save("poly_A_traj.xtc")
energy_logger.save_csv("poly_A_energy.csv")
print("wrote poly_A_traj.xtc and poly_A_energy.csv")
